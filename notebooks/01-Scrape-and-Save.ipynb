# %% [markdown]
# # Scrape & Save
#
# <br>
#
# ### Imports

# %%
from energynews import orchestrator

# %% [markdown]
# <br>
#
# ### User Inputs

# %%
data_dir = '../data'

# %% [markdown]
# <br>
#
# ### Saving Latest Data

# %%
orchestrator.scrape_and_save_data(data_dir)
orchestrator.update_readme_time('../README.md')
current_articles = orchestrator.combine_current_articles()
orchestrator.rebuild_posts(current_articles, '../docs')
# Out:
# c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\green_tech_media.py:24: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 24 of the file c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\green_tech_media.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   .pipe(lambda df: df.assign(description=df['description'].apply(lambda description: BeautifulSoup(description).get_text().replace('\xa0', ' ').replace('\n', ' ').replace('  ', ' ')[:250]+' ...')))
# c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\energy_live_news.py:35: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 35 of the file c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\energy_live_news.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.content)
# c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\business_green.py:26: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 26 of the file c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\business_green.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   .pipe(lambda df: df.assign(description=df['description'].apply(lambda description: BeautifulSoup(description).get_text()[:250]+'...')))
# c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\guardian.py:35: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 35 of the file c:\users\ayrto\desktop\side projects\energy-news\energynews\scrapers\guardian.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   .pipe(lambda df: df.assign(description=df['description'].apply(lambda description: BeautifulSoup(description).get_text()[:250]+'...')))
# Guest posts
# carbon brief
# science
# Features
# carbon brief
# science
# State of the climate
# carbon brief
# science
# Guest posts
# carbon brief
# science
# Sea ice
# carbon brief
# science
# Guest posts
# carbon brief
# science
# Webinars
# carbon brief
# science
# Guest posts
# carbon brief
# science
# Food and farming
# carbon brief
# science
# Guest posts
# carbon brief
# science
# Ice
# carbon brief
# science
# Guest posts
# carbon brief
# science
# Extreme weather
# carbon brief
# science
# Energy
# carbon brief
# energy
# Translations
# carbon brief
# energy
# Guest posts
# carbon brief
# energy
# Guest posts
# carbon brief
# energy
# Oil and gas
# carbon brief
# energy
# China Policy
# carbon brief
# energy
# Energy
# carbon brief
# energy
# Translations
# carbon brief
# energy
# Translations
# carbon brief
# energy
# Guest posts
# carbon brief
# energy
# Media analysis
# carbon brief
# policy
# US Policy
# carbon brief
# policy
# UK policy
# carbon brief
# policy
# US Policy
# carbon brief
# policy
# Policy
# carbon brief
# policy
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# energy-industry
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# bbc
# renewable-energy
# current news
# News
# current news
# Blogs
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# current news
# News
# Offshore Wind, ORE Catapult, GE
# renews
# Offshore Wind, siemens gamesa
# renews
# Offshore Wind, Ideol
# renews
# Offshore Wind, Fred Olsen Renewables
# renews
# Energy, Equinor, Panasonic
# renews
# Other news, SSE, Onshore Wind, Offshore Wind
# renews
# Vineyard Wind, Offshore Wind, Copenhagen Infrastructure Partners, Avangrid, Enercon, USA
# renews
# Offshore Wind, Boris Johnson, UK, Europe
# renews
# Sofia, RWE Renewables, Prysmian
# renews
# Solar, Energy Storage, RWE Renewables
# renews
# Offshore Wind, ORE Catapult
# renews
# Offshore Wind, Bladt Industries
# renews
# People, UK government, Boris Johnson
# renews
# Energy Storage, gore street capital, Fluence
# renews
# Onshore Wind, GE, Cypress, European Energy
# renews
# Onshore Wind, WindEurope
# renews
# Solar, Iberdrola
# renews
# Other news, Equinor
# renews
# Offshore Wind, grid, Kriegers Flak, Energinet, 50Hertz
# renews
# Solar, Enel Green Power
# renews
# Offshore Wind, SSE Renewables
# renews
# Offshore Wind, Dogger Bank, Sif, Smulders, SSE Renewables, Equinor
# renews
# finance, Offshore Wind, TenneT
# renews
# Offshore Wind, Orsted, siemens gamesa, Vattenfall, TenneT, 50Hertz, Elia, RTE
# renews
# Solar, Texas, Cubico
# renews
# Other news, RES
# renews
# solar, South Dakota
# renews
# Onshore Wind, Infrastructure and Energy Alternatives
# renews
# Other news, Siemens Energy
# renews
# Solar, BayWa, North Carolina
# renews
# Other news
# renews
# Offshore Wind
# renews
# Onshore Wind, Lekela
# renews
# Onshore Wind, Copenhagen Infrastructure Partners
# renews
# Grid, SSE, ScottishPower, National Grid ESO, Eastern Link
# renews
# finance, onshore wind, solar
# renews
# Onshore Wind, EDF Renewables, Tesco
# renews
# Wave and Tidal, CorPower
# renews
# Other news, Renewables Consulting Group
# renews
# Solar, EDF Renewables
# renews
# Offshore Wind, Fugro, NYK
# renews
# Solar, UK government, reMIX
# renews
# Offshore Wind, Equinor
# renews
# Offshore Wind, Moray East, Triton Knoll
# renews
# Offshore Wind, Dublin Array, RWE
# renews
# Offshore Wind, PKN Orlen, Baltic Power
# renews
# Offshore Wind, ScotWind, SSE, Marubeni, Copenhagen Infrastructure Partners
# renews
# Onshore Wind, European Energy
# renews
# Other news, EDF
# renews
# Offshore Wind, North Falls, SSE, RWE, Greater Gabbard
# renews
# Featured, Headlines, Press releases, Regional news, floating wind, IDEOL, Port of Cromarty Firth
# offshorewind
# Featured, Headlines, Dogger Bank, financial close, SSE
# offshorewind
# Featured, Headlines, Regional news, Atlantic Endeavor, Atlantic Wind Transfers, Blount Boats, Coastal Virginia Offshore Wind
# offshorewind
# Featured, Headlines, ELECTRODE, ORE Catapult, subsea cable failure
# offshorewind
# Featured, Headlines, Press releases, Regional news, Preferred Bidder Agreement, Prysmian, Sofia
# offshorewind
# Featured, Headlines, Aker Offshore Wind, floating wind, Principle Power
# offshorewind
# Featured, Headlines, Press releases, Regional news, Oceandock LX, Windthrust
# offshorewind
# Featured, Headlines, Dogger Bank, Dogger Bank A & B, foundations, monopiles, Sif Netherlands B.V., Smulders Projects, Transition pieces
# offshorewind
# Featured, Headlines, Bladt Industries, Burns & McDonnell, Eastern Seaboard
# offshorewind
# Featured, Headlines, Press releases, Regional news, Kiso-Jiban Consultants, Norwegian Geotechnical Institute
# offshorewind
# Wind, Markets
# recharge news
# Wind, Solar, Technology, Transition, Markets
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind, Markets
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind, Technology
# recharge news
# Technology, Transition, Markets
# recharge news
# Wind, Markets
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind, Solar, Technology, Transition, Markets
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind, Markets
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Technology, Transition
# recharge news
# Wind, Solar, Technology, Transition, Markets
# recharge news
# Wind, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind, Technology, Markets
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Circuit
# recharge news
# Wind, Technology, Markets
# recharge news
# Wind
# recharge news
# Wind, Transition
# recharge news
# Wind
# recharge news
# Wind
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind, Solar, Transition, Markets
# recharge news
# Wind
# recharge news
# Wind, Technology, Markets
# recharge news
# Grid Edge, Grid Optimization, Wind, Offshore Wind, Products &amp; Technology, Wind Projects, Energy, Water, News,
# green tech media
# Solar, Solar-Plus-Storage , Residential Solar, Markets &amp; Policy, Manufacturing, Utility-Scale Solar, Technology, Energy Storage, Energy, Policy, News,
# green tech media
# Solar, Solar-Plus-Storage , Energy Storage, News,
# green tech media
# Solar, Solar-Plus-Storage , Markets &amp; Policy, Grid Edge, Commercial &amp; Industrial Energy, Regulation &amp; Policy, Utilities, Energy Storage, Wind, Wind Markets &amp; Policy, Energy, Next Generation Utility, Other Energy, Finance &amp; VC, Policy, News,
# green tech media
# Solar, Residential Solar, Solar Projects, Markets &amp; Policy, Manufacturing, Utility-Scale Solar, Technology, Energy, Squared, The Solar Lead,
# green tech media
# Solar, Residential Solar, Solar Finance &amp; VC, Markets &amp; Policy, Research &amp; Analysis,
# green tech media
# Solar, Solar Finance &amp; VC, Solar Projects, Markets &amp; Policy, Grid Edge, Off Grid/Energy Access, News,
# green tech media
# Solar, Energy Storage, Long-Duration Storage, Wind, News,
# green tech media
# Grid Edge, Electric Vehicles, Regulation &amp; Policy, Grid Optimization, Batteries, Storage &amp; Fuel Cells, Utilities, Energy, Mobility, News,
# green tech media
# Solar, Solar Finance &amp; VC, Solar Projects, Utility-Scale Solar, Wind, Offshore Wind, Wind Finance &amp; VC, Wind Markets &amp; Policy, Wind Projects, News,
# green tech media
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# energy live news
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# business green
# nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bdaec3a8e3fa> in <module>
#       1 orchestrator.scrape_and_save_data(data_dir)
#       2 orchestrator.update_readme_time('../README.md')
# ----> 3 current_articles = orchestrator.combine_current_articles()
#       4 orchestrator.rebuild_posts(current_articles, '../docs')
#
# c:\users\ayrto\desktop\side projects\energy-news\energynews\orchestrator.py in combine_current_articles(data_path, sources)
#     158                             .pipe(clean_date_col)
#     159                             .pipe(clean_source_col)
# --> 160                             .pipe(format_tags)
#     161                             .sort_values('date', ascending=False)
#     162                             .fillna('')
#
# ~\anaconda3\envs\EnergyNews\lib\site-packages\pandas\core\generic.py in pipe(self, func, *args, **kwargs)
#    5046         ...  )  # doctest: +SKIP
#    5047     """
# -> 5048         return com.pipe(self, func, *args, **kwargs)
#    5049
#    5050     _shared_docs["aggregate"] = dedent(
#
# ~\anaconda3\envs\EnergyNews\lib\site-packages\pandas\core\common.py in pipe(obj, func, *args, **kwargs)
#     469         return func(*args, **kwargs)
#     470     else:
# --> 471         return func(obj, *args, **kwargs)
#     472
#     473
#
# c:\users\ayrto\desktop\side projects\energy-news\energynews\orchestrator.py in format_tags(df_articles)
#     101             if tag is not np.nan:
#     102                 print(tag)
# --> 103                 row_tags += [tag
#     104                              .lower()
#     105                              .replace('_', ' ')
#
# AttributeError: 'float' object has no attribute 'lower'
